# %% [markdown]
# # Setup

# %%
# NN and related metrics
from tensorflow import keras
import tensorflow as tf
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# General
import numpy as np
import os
import random
import pandas as pd

# Image and visualiztaion
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
from tabulate import tabulate
from PIL import Image
# Out:
# 2023-05-18 11:05:58.057609: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Specifying relevant paths
WORKING_DIRECTORY = os.getcwd()
DEPENDENCIES = os.path.join(WORKING_DIRECTORY, 'dependencies')
YOLO = os.path.join(DEPENDENCIES, 'yolov5')
YOLO_MODEL = os.path.join(YOLO, 'exam', 'models')
YOLO_DETECTION = os.path.join(YOLO, 'exam', 'detection', 'custom_trained_yolo_100', 'test_detection')

# %%
os.chdir(YOLO)

# %% [markdown]
# # Performing Predictions on test images

# %%
# !python detect.py --source 'datasets/test/images' --weights 'exam/models/custom_trained_yolo_100/weights/best.pt' --project 'exam/detection/custom_trained_yolo_100' --name test_detection
# Out:
# detect: weights=['exam/models/custom_trained_yolo_100/weights/best.pt'], source=datasets/test/images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=exam/detection/custom_trained_yolo_100, name=test_detection, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-165-ge382d4c Python-3.9.7 torch-2.0.0 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7029004 parameters, 0 gradients, 15.8 GFLOPs
# image 1/500 /Users/krebs/Documents/University/KAN-CDSCO1004U/dependencies/yolov5/datasets/test/images/000000003156.jpg: 640x640 1 person, 291.5ms
# image 2/500 /Users/krebs/Documents/University/KAN-CDSCO1004U/dependencies/yolov5/datasets/test/images/000000004395.jpg: 640x640 1 person, 258.3ms
# ...

# %% [markdown]
# # Visualizing Predictions

# %%
images = [Image.open(os.path.join(YOLO_DETECTION, img)) for img in os.listdir(YOLO_DETECTION)]

# %%
fig, axs = plt.subplots(4,2, figsize=(15,15))

for ax in axs.flatten():
    ind = random.randint(0, len(images)-1)
    ax.imshow(images[ind])
    ax.set_axis_off()

plt.tight_layout(pad=0)
